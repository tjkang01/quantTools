# %%
from load_and_summarize_data import *

# %%
# Load data for SPY 
data = Data(tickers=['SPY'], start_date='2001-01-02', end_date='2022-12-31')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Get returns and plot cumulative product
returns = data.rets
(1+returns).cumprod().plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
# Compute the worst 5 drawdowns and compare visually
drawdowns = compute_n_drawdowns(returns, num_dd=5)
print(drawdowns)
# Out:
#    Drawdown Peak Point Trough Point       Recovery Point
# 0 -0.551894 2007-10-09   2009-03-09  2012-08-16 00:00:00
# 1 -0.420286 2001-02-01   2002-10-09  2006-01-04 00:00:00
# 2 -0.337173 2020-02-19   2020-03-23  2020-08-10 00:00:00
# 3 -0.244964 2022-01-03   2022-10-12              Ongoing
# 4 -0.193489 2018-09-20   2018-12-24  2019-04-12 00:00:00

# %%
cum_ret = (1+returns).cumprod()
dd      = (cum_ret / cum_ret.cummax() - 1)
dd.plot()
# Out:
# <AxesSubplot: xlabel='Date'>
